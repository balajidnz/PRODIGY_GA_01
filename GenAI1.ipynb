# %%
#!pip install -q aitextgen

# !pip install git+https://github.com/scorixear/aitextgen

# !pip uninstall pytorch-lightning
# !pip install pytorch-lightning==2.0.0

import logging
logging.basicConfig(
        format="%(asctime)s — %(levelname)s — %(name)s — %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO
    )

from aitextgen import aitextgen
from aitextgen.colab import mount_gdrive, copy_file_from_gdrive
# Out:
# Collecting git+https://github.com/scorixear/aitextgen
#   Cloning https://github.com/scorixear/aitextgen to /tmp/pip-req-build-8cgxy9fa
#   Running command git clone --filter=blob:none --quiet https://github.com/scorixear/aitextgen /tmp/pip-req-build-8cgxy9fa
#   Resolved https://github.com/scorixear/aitextgen to commit 86e4be70a41a8740526f560d4ef0ba7647ed0f36
#   Preparing metadata (setup.py) ... done
# Collecting fire~=0.5.0 (from aitextgen==0.6.1)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-lightning~=2.0.0 (from aitextgen==0.6.1)
#   Downloading pytorch_lightning-2.0.9.post0-py3-none-any.whl.metadata (23 kB)
# Collecting transformers~=4.26.0 (from aitextgen==0.6.1)
#   Downloading transformers-4.26.1-py3-none-any.whl.metadata (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 5.6 MB/s eta 0:00:00
# Collecting torch~=1.13.0 (from aitextgen==0.6.1)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire~=0.5.0->aitextgen==0.6.1) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire~=0.5.0->aitextgen==0.6.1) (2.4.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning~=2.0.0->aitextgen==0.6.1) (1.26.4)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning~=2.0.0->aitextgen==0.6.1) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning~=2.0.0->aitextgen==0.6.1) (6.0.2)
# Requirement already satisfied: fsspec>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (2024.6.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning~=2.0.0->aitextgen==0.6.1)
#   Downloading torchmetrics-1.4.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning~=2.0.0->aitextgen==0.6.1) (24.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning~=2.0.0->aitextgen==0.6.1) (4.12.2)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning~=2.0.0->aitextgen==0.6.1)
#   Downloading lightning_utilities-0.11.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch~=1.13.0->aitextgen==0.6.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch~=1.13.0->aitextgen==0.6.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch~=1.13.0->aitextgen==0.6.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch~=1.13.0->aitextgen==0.6.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13.0->aitextgen==0.6.1) (71.0.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13.0->aitextgen==0.6.1) (0.44.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers~=4.26.0->aitextgen==0.6.1) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.26.0->aitextgen==0.6.1) (0.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.26.0->aitextgen==0.6.1) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers~=4.26.0->aitextgen==0.6.1) (2.32.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers~=4.26.0->aitextgen==0.6.1)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (3.10.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.26.0->aitextgen==0.6.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.26.0->aitextgen==0.6.1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.26.0->aitextgen==0.6.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.26.0->aitextgen==0.6.1) (2024.7.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning~=2.0.0->aitextgen==0.6.1) (4.0.3)
# Downloading pytorch_lightning-2.0.9.post0-py3-none-any.whl (727 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.7/727.7 kB 27.0 MB/s eta 0:00:00
# Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 28.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 42.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.3 MB/s eta 0:00:00
# Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 88.4 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.6-py3-none-any.whl (26 kB)
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.9 MB/s eta 0:00:00
# Downloading torchmetrics-1.4.1-py3-none-any.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.2/866.2 kB 50.4 MB/s eta 0:00:00
# Building wheels for collected packages: aitextgen, fire
#   Building wheel for aitextgen (setup.py) ... done
#   Created wheel for aitextgen: filename=aitextgen-0.6.1-py3-none-any.whl size=576121 sha256=40dc15adf2271f3b6368178303408d6c2328d4caa978b9b71b2aea40c54fdc36
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s02x9a10/wheels/da/43/80/b8ebb6c1777177246bb28bb04dd44f9b015c68d456ec866536
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116931 sha256=3c730bad898db867ea8860f678548cc8d5504396dda72c09d62f70c9a44dd682
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built aitextgen fire
# Installing collected packages: tokenizers, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, lightning-utilities, fire, nvidia-cudnn-cu11, transformers, torch, torchmetrics, pytorch-lightning, aitextgen
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0+cu121
#     Uninstalling torch-2.4.0+cu121:
#       Successfully uninstalled torch-2.4.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.4.0+cu121 requires torch==2.4.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.19.0+cu121 requires torch==2.4.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed aitextgen-0.6.1 fire-0.5.0 lightning-utilities-0.11.6 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 pytorch-lightning-2.0.9.post0 tokenizers-0.13.3 torch-1.13.1 torchmetrics-1.4.1 transformers-4.26.1
# Found existing installation: pytorch-lightning 2.0.9.post0
# Uninstalling pytorch-lightning-2.0.9.post0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/lightning_fabric/*
#     /usr/local/lib/python3.10/dist-packages/pytorch_lightning-2.0.9.post0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pytorch_lightning/*
# Proceed (Y/n)? y
#   Successfully uninstalled pytorch-lightning-2.0.9.post0
# Collecting pytorch-lightning==2.0.0
#   Downloading pytorch_lightning-2.0.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (1.26.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (1.13.1)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (6.0.2)
# Requirement already satisfied: fsspec>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (2024.6.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (1.4.1)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (24.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==2.0.0) (0.11.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (3.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.7.0->pytorch-lightning==2.0.0) (71.0.4)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning==2.0.0) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning==2.0.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning==2.0.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning==2.0.0) (11.7.99)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.11.0->pytorch-lightning==2.0.0) (0.44.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (4.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==2.0.0) (3.8)
# Downloading pytorch_lightning-2.0.0-py3-none-any.whl (715 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.6/715.6 kB 15.4 MB/s eta 0:00:00
# Installing collected packages: pytorch-lightning
# Successfully installed pytorch-lightning-2.0.0

# %%
# !nvidia-smi
# Out:
# Fri Aug 30 11:55:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
ai = aitextgen(tf_gpt2="124M", to_gpu=True)
# Out:
# INFO:aitextgen:Downloading the 124M GPT-2 TensorFlow weights/config from Google's servers
# Fetching checkpoint:   0%|          | 0.00/77.0 [00:00<?, ?it/s]
# Fetching hparams.json:   0%|          | 0.00/90.0 [00:00<?, ?it/s]
# Fetching model.ckpt.data-00000-of-00001:   0%|          | 0.00/498M [00:00<?, ?it/s]
# Fetching model.ckpt.index:   0%|          | 0.00/5.21k [00:00<?, ?it/s]
# Fetching model.ckpt.meta:   0%|          | 0.00/471k [00:00<?, ?it/s]
# INFO:aitextgen:Converting the 124M GPT-2 TensorFlow weights to PyTorch.
# Converting TensorFlow checkpoint from /content/aitextgen/124M
# Loading TF weight model/h0/attn/c_attn/b with shape [2304]
# Loading TF weight model/h0/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h0/attn/c_proj/b with shape [768]
# Loading TF weight model/h0/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h0/ln_1/b with shape [768]
# Loading TF weight model/h0/ln_1/g with shape [768]
# Loading TF weight model/h0/ln_2/b with shape [768]
# Loading TF weight model/h0/ln_2/g with shape [768]
# Loading TF weight model/h0/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h0/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h0/mlp/c_proj/b with shape [768]
# Loading TF weight model/h0/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h1/attn/c_attn/b with shape [2304]
# Loading TF weight model/h1/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h1/attn/c_proj/b with shape [768]
# Loading TF weight model/h1/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h1/ln_1/b with shape [768]
# Loading TF weight model/h1/ln_1/g with shape [768]
# Loading TF weight model/h1/ln_2/b with shape [768]
# Loading TF weight model/h1/ln_2/g with shape [768]
# Loading TF weight model/h1/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h1/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h1/mlp/c_proj/b with shape [768]
# Loading TF weight model/h1/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h10/attn/c_attn/b with shape [2304]
# Loading TF weight model/h10/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h10/attn/c_proj/b with shape [768]
# Loading TF weight model/h10/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h10/ln_1/b with shape [768]
# Loading TF weight model/h10/ln_1/g with shape [768]
# Loading TF weight model/h10/ln_2/b with shape [768]
# Loading TF weight model/h10/ln_2/g with shape [768]
# Loading TF weight model/h10/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h10/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h10/mlp/c_proj/b with shape [768]
# Loading TF weight model/h10/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h11/attn/c_attn/b with shape [2304]
# Loading TF weight model/h11/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h11/attn/c_proj/b with shape [768]
# Loading TF weight model/h11/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h11/ln_1/b with shape [768]
# Loading TF weight model/h11/ln_1/g with shape [768]
# Loading TF weight model/h11/ln_2/b with shape [768]
# Loading TF weight model/h11/ln_2/g with shape [768]
# Loading TF weight model/h11/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h11/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h11/mlp/c_proj/b with shape [768]
# Loading TF weight model/h11/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h2/attn/c_attn/b with shape [2304]
# Loading TF weight model/h2/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h2/attn/c_proj/b with shape [768]
# Loading TF weight model/h2/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h2/ln_1/b with shape [768]
# Loading TF weight model/h2/ln_1/g with shape [768]
# Loading TF weight model/h2/ln_2/b with shape [768]
# Loading TF weight model/h2/ln_2/g with shape [768]
# Loading TF weight model/h2/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h2/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h2/mlp/c_proj/b with shape [768]
# Loading TF weight model/h2/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h3/attn/c_attn/b with shape [2304]
# Loading TF weight model/h3/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h3/attn/c_proj/b with shape [768]
# Loading TF weight model/h3/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h3/ln_1/b with shape [768]
# Loading TF weight model/h3/ln_1/g with shape [768]
# Loading TF weight model/h3/ln_2/b with shape [768]
# Loading TF weight model/h3/ln_2/g with shape [768]
# Loading TF weight model/h3/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h3/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h3/mlp/c_proj/b with shape [768]
# Loading TF weight model/h3/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h4/attn/c_attn/b with shape [2304]
# Loading TF weight model/h4/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h4/attn/c_proj/b with shape [768]
# Loading TF weight model/h4/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h4/ln_1/b with shape [768]
# Loading TF weight model/h4/ln_1/g with shape [768]
# Loading TF weight model/h4/ln_2/b with shape [768]
# Loading TF weight model/h4/ln_2/g with shape [768]
# Loading TF weight model/h4/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h4/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h4/mlp/c_proj/b with shape [768]
# Loading TF weight model/h4/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h5/attn/c_attn/b with shape [2304]
# Loading TF weight model/h5/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h5/attn/c_proj/b with shape [768]
# Loading TF weight model/h5/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h5/ln_1/b with shape [768]
# Loading TF weight model/h5/ln_1/g with shape [768]
# Loading TF weight model/h5/ln_2/b with shape [768]
# Loading TF weight model/h5/ln_2/g with shape [768]
# Loading TF weight model/h5/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h5/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h5/mlp/c_proj/b with shape [768]
# Loading TF weight model/h5/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h6/attn/c_attn/b with shape [2304]
# Loading TF weight model/h6/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h6/attn/c_proj/b with shape [768]
# Loading TF weight model/h6/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h6/ln_1/b with shape [768]
# Loading TF weight model/h6/ln_1/g with shape [768]
# Loading TF weight model/h6/ln_2/b with shape [768]
# Loading TF weight model/h6/ln_2/g with shape [768]
# Loading TF weight model/h6/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h6/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h6/mlp/c_proj/b with shape [768]
# Loading TF weight model/h6/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h7/attn/c_attn/b with shape [2304]
# Loading TF weight model/h7/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h7/attn/c_proj/b with shape [768]
# Loading TF weight model/h7/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h7/ln_1/b with shape [768]
# Loading TF weight model/h7/ln_1/g with shape [768]
# Loading TF weight model/h7/ln_2/b with shape [768]
# Loading TF weight model/h7/ln_2/g with shape [768]
# Loading TF weight model/h7/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h7/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h7/mlp/c_proj/b with shape [768]
# Loading TF weight model/h7/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h8/attn/c_attn/b with shape [2304]
# Loading TF weight model/h8/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h8/attn/c_proj/b with shape [768]
# Loading TF weight model/h8/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h8/ln_1/b with shape [768]
# Loading TF weight model/h8/ln_1/g with shape [768]
# Loading TF weight model/h8/ln_2/b with shape [768]
# Loading TF weight model/h8/ln_2/g with shape [768]
# Loading TF weight model/h8/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h8/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h8/mlp/c_proj/b with shape [768]
# Loading TF weight model/h8/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/h9/attn/c_attn/b with shape [2304]
# Loading TF weight model/h9/attn/c_attn/w with shape [1, 768, 2304]
# Loading TF weight model/h9/attn/c_proj/b with shape [768]
# Loading TF weight model/h9/attn/c_proj/w with shape [1, 768, 768]
# Loading TF weight model/h9/ln_1/b with shape [768]
# Loading TF weight model/h9/ln_1/g with shape [768]
# Loading TF weight model/h9/ln_2/b with shape [768]
# Loading TF weight model/h9/ln_2/g with shape [768]
# Loading TF weight model/h9/mlp/c_fc/b with shape [3072]
# Loading TF weight model/h9/mlp/c_fc/w with shape [1, 768, 3072]
# Loading TF weight model/h9/mlp/c_proj/b with shape [768]
# Loading TF weight model/h9/mlp/c_proj/w with shape [1, 3072, 768]
# Loading TF weight model/ln_f/b with shape [768]
# Loading TF weight model/ln_f/g with shape [768]
# Loading TF weight model/wpe with shape [1024, 768]
# Loading TF weight model/wte with shape [50257, 768]
# Initialize PyTorch weight ['h0', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h0', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h0', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h0', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h0', 'ln_1', 'b']
# Initialize PyTorch weight ['h0', 'ln_1', 'g']
# Initialize PyTorch weight ['h0', 'ln_2', 'b']
# Initialize PyTorch weight ['h0', 'ln_2', 'g']
# Initialize PyTorch weight ['h0', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h0', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h0', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h0', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h1', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h1', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h1', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h1', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h1', 'ln_1', 'b']
# Initialize PyTorch weight ['h1', 'ln_1', 'g']
# Initialize PyTorch weight ['h1', 'ln_2', 'b']
# Initialize PyTorch weight ['h1', 'ln_2', 'g']
# Initialize PyTorch weight ['h1', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h1', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h1', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h1', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h10', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h10', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h10', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h10', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h10', 'ln_1', 'b']
# Initialize PyTorch weight ['h10', 'ln_1', 'g']
# Initialize PyTorch weight ['h10', 'ln_2', 'b']
# Initialize PyTorch weight ['h10', 'ln_2', 'g']
# Initialize PyTorch weight ['h10', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h10', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h10', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h10', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h11', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h11', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h11', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h11', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h11', 'ln_1', 'b']
# Initialize PyTorch weight ['h11', 'ln_1', 'g']
# Initialize PyTorch weight ['h11', 'ln_2', 'b']
# Initialize PyTorch weight ['h11', 'ln_2', 'g']
# Initialize PyTorch weight ['h11', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h11', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h11', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h11', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h2', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h2', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h2', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h2', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h2', 'ln_1', 'b']
# Initialize PyTorch weight ['h2', 'ln_1', 'g']
# Initialize PyTorch weight ['h2', 'ln_2', 'b']
# Initialize PyTorch weight ['h2', 'ln_2', 'g']
# Initialize PyTorch weight ['h2', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h2', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h2', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h2', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h3', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h3', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h3', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h3', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h3', 'ln_1', 'b']
# Initialize PyTorch weight ['h3', 'ln_1', 'g']
# Initialize PyTorch weight ['h3', 'ln_2', 'b']
# Initialize PyTorch weight ['h3', 'ln_2', 'g']
# Initialize PyTorch weight ['h3', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h3', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h3', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h3', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h4', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h4', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h4', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h4', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h4', 'ln_1', 'b']
# Initialize PyTorch weight ['h4', 'ln_1', 'g']
# Initialize PyTorch weight ['h4', 'ln_2', 'b']
# Initialize PyTorch weight ['h4', 'ln_2', 'g']
# Initialize PyTorch weight ['h4', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h4', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h4', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h4', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h5', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h5', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h5', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h5', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h5', 'ln_1', 'b']
# Initialize PyTorch weight ['h5', 'ln_1', 'g']
# Initialize PyTorch weight ['h5', 'ln_2', 'b']
# Initialize PyTorch weight ['h5', 'ln_2', 'g']
# Initialize PyTorch weight ['h5', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h5', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h5', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h5', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h6', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h6', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h6', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h6', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h6', 'ln_1', 'b']
# Initialize PyTorch weight ['h6', 'ln_1', 'g']
# Initialize PyTorch weight ['h6', 'ln_2', 'b']
# Initialize PyTorch weight ['h6', 'ln_2', 'g']
# Initialize PyTorch weight ['h6', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h6', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h6', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h6', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h7', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h7', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h7', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h7', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h7', 'ln_1', 'b']
# Initialize PyTorch weight ['h7', 'ln_1', 'g']
# Initialize PyTorch weight ['h7', 'ln_2', 'b']
# Initialize PyTorch weight ['h7', 'ln_2', 'g']
# Initialize PyTorch weight ['h7', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h7', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h7', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h7', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h8', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h8', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h8', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h8', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h8', 'ln_1', 'b']
# Initialize PyTorch weight ['h8', 'ln_1', 'g']
# Initialize PyTorch weight ['h8', 'ln_2', 'b']
# Initialize PyTorch weight ['h8', 'ln_2', 'g']
# Initialize PyTorch weight ['h8', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h8', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h8', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h8', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['h9', 'attn', 'c_attn', 'b']
# Initialize PyTorch weight ['h9', 'attn', 'c_attn', 'w']
# Initialize PyTorch weight ['h9', 'attn', 'c_proj', 'b']
# Initialize PyTorch weight ['h9', 'attn', 'c_proj', 'w']
# Initialize PyTorch weight ['h9', 'ln_1', 'b']
# Initialize PyTorch weight ['h9', 'ln_1', 'g']
# Initialize PyTorch weight ['h9', 'ln_2', 'b']
# Initialize PyTorch weight ['h9', 'ln_2', 'g']
# Initialize PyTorch weight ['h9', 'mlp', 'c_fc', 'b']
# Initialize PyTorch weight ['h9', 'mlp', 'c_fc', 'w']
# Initialize PyTorch weight ['h9', 'mlp', 'c_proj', 'b']
# Initialize PyTorch weight ['h9', 'mlp', 'c_proj', 'w']
# Initialize PyTorch weight ['ln_f', 'b']
# Initialize PyTorch weight ['ln_f', 'g']
# Initialize PyTorch weight ['wpe']
# Initialize PyTorch weight ['wte']
# Save PyTorch model to aitextgen/pytorch_model.bin
# INFO:aitextgen:Loading 124M GPT-2 model from /aitextgen.
# Save configuration file to aitextgen/config.json
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# INFO:aitextgen:GPT2 loaded with 124M parameters.
# INFO:aitextgen:Using the default GPT-2 Tokenizer.

# %%
mount_gdrive()
# Out:
# Mounted at /content/drive

# %%
file_name = "input.txt"

# %%
copy_file_from_gdrive(file_name)

# %%
ai.train(file_name,
         line_by_line=False,
         from_cache=False,
         num_steps=3000,
         generate_every=1000,
         save_every=1000,
         save_gdrive=False,
         learning_rate=1e-3,
         fp16=False,
         batch_size=1,
         )
# Out:
# INFO:aitextgen:Loading text from input.txt with generation length of 1024.
#   0%|          | 0/40000 [00:00<?, ?it/s]
# INFO:aitextgen.TokenDataset:Encoding 40,000 sets of tokens from input.txt.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type            | Params
# ------------------------------------------
# 0 | model | GPT2LMHeadModel | 124 M
# ------------------------------------------
# 124 M     Trainable params
# 0         Non-trainable params
# 124 M     Total params
# 497.759   Total estimated model params size (MB)
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Configuration saved in trained_model/generation_config.json
# 1,000 steps reached: saving model to /trained_model
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 1,000 steps reached: generating sample texts.
# ==========
#
# POMPEY:
#
# ANGELO:
# I do crave the best: and let me entreat you
# And bid me welcome to your worshipful worship.
#
# ANGELO:
# I thank thee, lords; I will attend my lord
# And watch the king's pleasure.
#
# ANGELO:
# God ye good denials!
#
# ANGEL:
# I thank thee, gentlemen: let me go:
# I long to watch thy mistress and the queen.
#
# Provost:
# I thank thee, good lord; I thank thee for my good night.
#
# ANGELO:
# I thank your good worship; and be satisfied.
#
# ANGELO:
# I thank your worship; and, I would say,
# I thank my good lord; and yet I should be pleased.
#
# DUKE OF AUMERLE:
# I thank your grace. I respect you as far
# As you with my most good night: where I may find it,
# I mean to purge my falsehood with all dishonour.
#
#
# ==========
# Configuration saved in trained_model/generation_config.json
# 2,000 steps reached: saving model to /trained_model
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 2,000 steps reached: generating sample texts.
# ==========
# ,
# As if it were so.
#
# KING EDWARD IV:
# Then say no more:
# When, Harry, wert thou not in thy bed,
# Do thou not bid me sleep.
#
# QUEEN MARGARET:
# Then, for I will say, thou shalt not bed:
# If thou wilt bed, then wilt thou hunt;
# And wilt thou hunt? thy horses shall be trapp'd.
#
# KING EDWARD IV:
# My horse shall be trapp'd, and my horse shall be trapp'd.
#
# QUEEN MARGARET:
# How now, fair sovereign, what say'st thou to this?
#
# KING EDWARD IV:
# A thousand flatterers are at hand,
# And thus I seal I truth, and bid adieu.
#
# WARWICK:
# Why, now, fair lords, let's away.
#
# QUEEN MARGARET:
# My sovereigns to Edward hath a son a daughter;
# And now will I be Edward's champion.
#
# KING
# ==========
# Configuration saved in trained_model/generation_config.json
# 3,000 steps reached: saving model to /trained_model
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 3,000 steps reached: generating sample texts.
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=3000` reached.
# ==========
#
# CAMILLO:
# The gods sit in hourly as clouds;
# And every cat and dog
# But Romeo's; Romeo,--
# In every cabin, deprived, canst thou quake,
# Save your way, fell Clifford? and I, in every cabin,
# In my command, hie thee to thy heart,
# That I may call my person, that even here I
# I lay my bones there: thriceenting madam,
# I never saw the conquer yet,
# Till the conquer'd foe in my cheeks,
# With tears' caps up report of the king
# Which I, weeping queen, have shamed me
# With vain was grown into despair:
# And, as I guess, my father
# Well might the prince be author of my love,
# For I can never be so contented.
#
# CAMILLO:
# Be of comfort;
# We need no manners left.
#
# POLIXENES:
# Where is my father?
#
# CAMILLO:
# Not of my father's, nor no man of mine,
# But thus your father
# ==========
# INFO:aitextgen:Saving trained model pytorch_model.bin to /trained_model
# Configuration saved in trained_model/generation_config.json

# %%
ai = aitextgen(model_folder="trained_model", to_gpu=True)
# Out:
# INFO:aitextgen:Loading model from provided weights and config in /trained_model.
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# loading configuration file trained_model/generation_config.json
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# INFO:aitextgen:GPT2 loaded with 124M parameters.
# INFO:aitextgen:Using the default GPT-2 Tokenizer.

# %% [markdown]
# Just text generate

# %%
ai.generate()
# Out:
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# , then, as I guess,
# March on to mark his honour as you
# Each one by the highness of the field.
#
# EDWARD:
# Amen, say we: we will follow you.
#
# RICHMOND:
# We will, sure on't.
#
# EDWARD:
# Be ready, in the field; be resolute.
#
# RICHMOND:
# The weary sun hath made a golden set,
# And by the bright track of his fiery car,
# Gives signal, of a goodly day to-morrow.
# Sir William Brandon, you shall bear my standard.
# Give me some ink and paper.
# What, is my beaver easier than it was?
#
# EDWARD:
# It is, my lord.
#
# RICHMOND:
# Good Peter, to hide her face;
# Her mother is too heavy, too heavy,
# Too heavy, too heavy, too heavy, too heavy;
# Too light, too light, too light!
#
# EDWARD:
# What, wilt thou draw thy forces

# %%
ai.generate(
    n=5,
    prompt="ROMEO:",
    max_length=256,
    temperature=1.0,
    top_p=0.9,
)
# Out:
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
# ROMEO:
# Good even. Friar John, speak.
#
# Nurse:
# God and Saint George for our Romans!
#
# JULIET:
# Saints do not move, though grant for prayers' sake.
#
# ROMEO:
# Then move not, while my prayer's effect I take.
# Thus from my lips, my sin is purged.
#
# ROMEO:
# Then have my lips the sin that they have took.
#
# Nurse:
# We pray, sir, here do I lend a hundred years' worth.
#
# ROMEO:
# You have sin; I must have as little sin to sin as sin.
#
# ROMEO:
#  sin from thy lips? O trespass sweetly urged!
# Give me my sin again.
#
# Nurse:
# You kiss by me, as if you kiss'd.
#
# ROMEO:
#
# Nurse:
# Madam, your mother craves a word with you.
#
# ROMEO:
# What is her mother?
#
# ROMEO:
#
# ==========
# ROMEO:
# But, master mayor: these news of the prince's doom
# Is that a prisoner nine have done me wrongfully:
# Besides two galliases, the rest
# Which have beside well appeared'd in the world;
# Besides, the king's name is a creature, not
# Of the king's royal bed, which owe
# A moat defensive to the prince's love, which owe
# A moat defensive to the prince's love.
# What, what's the news?
#
# BALTHASAR:
# Good news, good news; here is such news as
# you never heard of.
#
# BALTHASAR:
# Who is't?
#
# BALTHASAR:
# O, sir, it is no news;
# Who is sojealous of his guard
# As he is jealous.
#
# BALTHASAR:
# Why, what is it?
#
# BALTHASAR:
# Because my lord and prince agree with you,
# Because he thinks the king is dead.
#
# BALTHASAR:
# Now, fair madam,
# ==========
# ROMEO:
# God save thee from thy angry wit!
# Thy drugs, toads, bills, bills, bills, and canopies,
# Fine linen, Turkey cushions boss'd with pearl,
# Valance of Venice gold in needlework,
# Valance of Venice gold in needlework,
# Pewter and brass and brass and all things that belong
# To housekeeping and the admired beauties: thou barr'st,
# Like to a block, thou ladder wherewithal
# There's chair-restrained and eat;
# That shows thee all, and is not quickly.
#
# BENVOLIO:
# Have patience, madam.
# We have strict statutes and most biting laws,
# Which we would not have you to do in these;
# Nor a partial slander sought once;
# But what it bodes, it will;
# For the most of them say is my royal self.
#
# BENVOLIO:
# Good my lord, your honour is alter'd from grudging
# The graces of your highness' frown;
# Which I will some days do, some hour,
#
# ==========
# ROMEO:
# 'Tis torture to me: thou art deceived in me,
# And I will apprehend thee.
#
# FRIAR LAURENCE:
# Be plain, good father. Friar, give me thy hand;
# Beseech you, say it is not sin at all,
# In this troublous time, I will be thy heir;
# And this alliance must be call'd jointure:
# What is it that calls home thy brother?
# Or, be so it, that great currish-heartedman
# Still to remember wrongs? Daughter, speak it again;
# Let's ha' thee speak no more; thou wilt say it is:
# And, madam, speak it again:
# As with a vow, I will be satisfied;
# And, madam, thou canst not frown, say 'tis not good.
#
# FRIAR LAURENCE:
# Be plain, good father; I must not frown.
#
# ROMEO:
# Sawares thy daughter?
#
# FRIAR LAURENCE:
# Yea, speak it again: thou
# ==========
# ROMEO:
# What is't?
#
# MISTRESS OVERDONE:
# 'Tis nothing less: conceit is still derived
# From a fore-custom'd lady, that you
# wore not her!
#
# DORCAS:
# O, very well;
# I must have leave to pass.
#
# MISTRESS OVERDONE:
# O, very well; I must go too;
# It is no more, I pray.
#
# DORCAS:
# What?
#
# MISTRESS OVERDONE:
# It's a sickness
# Which puts some of us to smile at this disease,
# And so it goes, it needs be, to be prevented.
#
# DORCAS:
# It is not a world to see, but to be heard,
# Not to be heard, therefore.
#
# MISTRESS OVERDONE:
# Yet thus it stands, you hear:--
# As if it were sin to take something life
# From thine to make a sick man.
#
# DOR

# %%
num_files = 5

for _ in range(num_files):
  ai.generate_to_file(n=1000,
                     batch_size=50,
                     prompt="ROMEO:",
                     max_length=256,
                     temperature=1.0,
                     top_p=0.9)
# Out:
# INFO:aitextgen:Generating 1,000 texts to ATG_20240830_124552_46055229.txt
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# INFO:aitextgen:Generating 1,000 texts to ATG_20240830_124756_49135301.txt
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# INFO:aitextgen:Generating 1,000 texts to ATG_20240830_124959_46321598.txt
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# INFO:aitextgen:Generating 1,000 texts to ATG_20240830_125202_46343906.txt
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# INFO:aitextgen:Generating 1,000 texts to ATG_20240830_125406_33460735.txt
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256,
#   "transformers_version": "4.26.1"
# }
